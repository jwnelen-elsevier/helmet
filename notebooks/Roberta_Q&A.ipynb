# %%
# !pip install transformers datasets torch -q

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from datasets import load_dataset

# %%
# dataset = load_dataset("squad")

# example = dataset["train"][0]
# example

from datasets import load_dataset
dataset = load_dataset("AmazonScience/massive", "en-US", split='test')
# Out:
# Downloading data: 100%|██████████| 676k/676k [00:00<00:00, 979kB/s]
# Downloading data: 100%|██████████| 140k/140k [00:00<00:00, 509kB/s]
# Downloading data: 100%|██████████| 191k/191k [00:00<00:00, 357kB/s]
# Generating train split: 100%|██████████| 11514/11514 [00:00<00:00, 383657.06 examples/s]
# Generating validation split: 100%|██████████| 2033/2033 [00:00<00:00, 227375.07 examples/s]
# Generating test split: 100%|██████████| 2974/2974 [00:00<00:00, 203492.07 examples/s]

# %%
# model_name = "deepset/roberta-base-squad2"

# model = AutoModelForQuestionAnswering.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)

name = "qanastek/XLMRoberta-Alexa-Intents-Classification"
tokenizer = AutoTokenizer.from_pretrained(name)
model = AutoModelForSequenceClassification.from_pretrained(name)

# %%
model.config.id2label

# %%
inputs = tokenizer(
    example['question'],
    example['context'],
    return_tensors='pt'
)

# %%
import requests

url = "http://localhost:4000"

# myobj = {
#     'name': self.name,
#     'model': self.model.config.model_type,
#     'text': e.text,
#     'tokens': e.tokens,
#     'attributions': scores
# }
    

def send_body(body):
    # posting it to the xai-platform
    u = f"{url}/runs"
    requests.post(u, json = body)

# %%
with torch.no_grad():
    outputs = model(**inputs)

start_idx = torch.argmax(outputs.start_logits)
end_idx = torch.argmax(outputs.end_logits)

r = inputs['input_ids'][0][start_idx:end_idx + 1]
predicted_answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(r))

# %%
print(f"Answer: {predicted_answer}")
# Out:
# Answer 1:  Saint Bernadette Soubirous

# %%
def predict(inputs, token_type_ids=None, position_ids=None, attention_mask=None):
    output = model(inputs, token_type_ids=token_type_ids,
                 position_ids=position_ids, attention_mask=attention_mask, )
    return output.start_logits, output.end_logits

# %%
def squad_pos_forward_func(inputs, token_type_ids=None, position_ids=None, attention_mask=None, position=0):
    pred = predict(inputs,
                   token_type_ids=token_type_ids,
                   position_ids=position_ids,
                   attention_mask=attention_mask)
    pred = pred[position]
    return pred.max(1).values

# %%
# !pip install captum -q
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from transformers.tokenization_utils_base import BatchEncoding
from captum.attr import InputXGradient

class ModelHelper:
    """
    Wrapper class to interface with HuggingFace models
    """

    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer

    def _tokenize(self, text: str, **tok_kwargs) -> BatchEncoding:
        return self.tokenizer(text, return_tensors="pt", truncation=True, **tok_kwargs)
    
    def get_input_embeds(self, text: str) -> torch.Tensor:
        """Extract input embeddings

        :param text str: the string to extract embeddings from.
        """
        item = self._tokenize(text)
        item = {k: v.to(self.model.device) for k, v in item.items()}
        embeddings = self._get_input_embeds_from_ids(item["input_ids"][0])
        embeddings = embeddings.unsqueeze(0)
        return embeddings

    def _get_input_embeds_from_ids(self, ids) -> torch.Tensor:
        return self.model.get_input_embeddings()(ids)

# %%
dataset[11]
# Out:
# {'id': '59',
#  'locale': 'en-US',
#  'partition': 'test',
#  'scenario': 16,
#  'intent': 52,
#  'utt': 'cancel my seven am alarm',
#  'annot_utt': 'cancel my [time : seven am] alarm',
#  'worker_id': '70',
#  'slot_method': {'slot': [], 'method': []},
#  'judgments': {'worker_id': [],
#   'intent_score': [],
#   'slots_score': [],
#   'grammar_score': [],
#   'spelling_score': [],
#   'language_identification': []}}

# %%
text = dataset[11]["utt"]
target = 1
model_helper = ModelHelper(model, tokenizer)

item = tokenizer(text=text, return_tensors='pt')
input_len = item["attention_mask"].sum().item()

def func(input_embeds):
    outputs = model_helper.model(
        inputs_embeds=input_embeds, attention_mask=item["attention_mask"]
    )
    return outputs.logits

dl = InputXGradient(func)
inputs = model_helper.get_input_embeds(text)

attr = dl.attribute(inputs, target=target)

# %%
attr
# Out:
# tensor([[[-2.3997e-04, -1.9094e-04,  2.2474e-04,  ...,  1.3069e-03,
#            6.3588e-05, -2.2603e-04],
#          [-7.6990e-04,  7.4859e-05, -2.5630e-04,  ...,  1.0900e-03,
#           -1.0825e-02,  9.6698e-03],
#          [-1.8734e-05,  2.8926e-05, -5.6548e-05,  ...,  1.2224e-04,
#           -2.0386e-03,  2.3753e-03],
#          ...,
#          [-1.8494e-05, -2.5548e-04, -9.9333e-04,  ..., -6.2607e-04,
#           -2.1831e-03, -4.7613e-03],
#          [ 3.0155e-05,  1.2161e-03, -3.6249e-04,  ..., -5.1833e-03,
#            1.8906e-03,  1.0435e-03],
#          [-1.5737e-03, -2.9266e-04, -7.4562e-04,  ..., -1.0935e-03,
#           -3.4146e-04,  3.5755e-03]]], grad_fn=<MulBackward0>)

# %%
attr = attr[0, :input_len, :].detach().cpu()

# pool over hidden size
attr = attr.sum(-1).numpy()
attr
# Out:
# array([-0.00679844,  0.13200764, -0.01119853,  0.00851695, -0.00574999,
#         0.03258043, -0.00890212], dtype=float32)

# %%
# !pip install inseq
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.org/simple
# Collecting inseq
#   Downloading inseq-0.5.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: captum>=0.6.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from inseq) (0.7.0)
# Collecting jaxtyping<0.3.0,>=0.2.23 (from inseq)
#   Downloading jaxtyping-0.2.25-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: matplotlib>=3.5.3 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from inseq) (3.8.2)
# Requirement already satisfied: numpy>=1.21.6 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from inseq) (1.26.3)
# Collecting poethepoet>=0.13.1 (from inseq)
#   Downloading poethepoet-0.24.4-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: protobuf>=3.20.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from inseq) (4.25.1)
# Collecting rich>=10.13.0 (from inseq)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.8.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from inseq) (1.11.4)
# Collecting torch==2.0.0 (from inseq)
#   Downloading torch-2.0.0-cp39-none-macosx_10_9_x86_64.whl (139.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 MB 633.5 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>=4.64.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from inseq) (4.66.1)
# Requirement already satisfied: transformers>=4.22.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (4.37.0)
# Collecting typeguard<=2.13.3 (from inseq)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: filelock in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from torch==2.0.0->inseq) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/nelenj/.local/lib/python3.9/site-packages (from torch==2.0.0->inseq) (4.9.0)
# Requirement already satisfied: sympy in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from torch==2.0.0->inseq) (1.12)
# Requirement already satisfied: networkx in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from torch==2.0.0->inseq) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from torch==2.0.0->inseq) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/nelenj/.local/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nelenj/.local/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from matplotlib>=3.5.3->inseq) (6.1.1)
# Collecting pastel<0.3.0,>=0.2.1 (from poethepoet>=0.13.1->inseq)
#   Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Collecting tomli>=1.2.2 (from poethepoet>=0.13.1->inseq)
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.13.0->inseq)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/nelenj/.local/lib/python3.9/site-packages (from rich>=10.13.0->inseq) (2.17.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (2023.12.25)
# Requirement already satisfied: requests in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (0.4.2)
# Collecting accelerate>=0.21.0 (from transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq)
#   Downloading accelerate-0.26.1-py3-none-any.whl.metadata (18 kB)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq)
#   Downloading sentencepiece-0.1.99-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: psutil in /Users/nelenj/.local/lib/python3.9/site-packages (from accelerate>=0.21.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (5.9.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (2023.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nelenj/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.3->inseq) (3.17.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.13.0->inseq)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /Users/nelenj/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->inseq) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from jinja2->torch==2.0.0->inseq) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from requests->transformers>=4.22.0->transformers[sentencepiece,tokenizers,torch]>=4.22.0->inseq) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/nelenj/miniconda3/envs/phoenix/lib/python3.9/site-packages (from sympy->torch==2.0.0->inseq) (1.3.0)
# Downloading inseq-0.5.0-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 858.4 kB/s eta 0:00:00 0:00:01m
# Downloading jaxtyping-0.2.25-py3-none-any.whl (39 kB)
# Downloading poethepoet-0.24.4-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 975.8 kB/s eta 0:00:000:00:01
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 1.3 MB/s eta 0:00:00a 0:00:01m
# Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 1.3 MB/s eta 0:00:0000:0100:01m
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 818.4 kB/s eta 0:00:000:00:010m
# Installing collected packages: sentencepiece, typeguard, tomli, pastel, mdurl, torch, poethepoet, markdown-it-py, jaxtyping, rich, accelerate, inseq
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
# Successfully installed accelerate-0.26.1 inseq-0.5.0 jaxtyping-0.2.25 markdown-it-py-3.0.0 mdurl-0.1.2 pastel-0.2.1 poethepoet-0.24.4 rich-13.7.0 sentencepiece-0.1.99 tomli-2.0.1 torch-2.0.0 typeguard-2.13.3
